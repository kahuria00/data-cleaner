# %%
import pandas as pd
import numpy as np
from datetime import date

data_dump = pd.read_excel('BookingReport.xlsx')
data_dump.head(5)
# Out:
#        LAKELAND CARGO LOGISTICS Ltd Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                    Booking Report        NaN        NaN        NaN
# 1  Date: 08-Apr-2022 To 10-Apr-2022        NaN        NaN        NaN
# 2                   BranchName: All        NaN        NaN        NaN
# 3         Destination City: --All--        NaN        NaN        NaN
# 4                           Summary        NaN        NaN        NaN
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 10 Unnamed: 11                       Unnamed: 12 Unnamed: 13  \
# ...

# %%
data_dump = data_dump.drop(labels=range(0,15),axis=0)
data_dump = data_dump.reset_index(drop=True)
data_dump.columns = data_dump.iloc[0]
data_dump = data_dump.drop([0],axis=0)
data_dump.head(3)
# Out:
# 0 SR.        WB No. Destination City               Destination Branch  \
# 1   1    LLKSM\3737          Mombasa                 MOMBASA LAKELAND
# 2   2    LLKSM\3738           Nakuru                  NAKURU LAKELAND
# 3   3   LLMSA\28527          Nairobi  HO_LAKELAND CARGO LOGISTICS Ltd
#
# 0     Booking DateTime Booked By User  Booked By Branch    Sender Name  \
# 1  2022-04-08 08:07:00   Evans Ojwang   KISUMU LAKELAND       Akshay K
# 2  2022-04-08 08:08:00   Evans Ojwang   KISUMU LAKELAND  Vision Techno
# 3  2022-04-08 09:18:00       Sudi Ali  MOMBASA LAKELAND  clinton lyall
#
# 0      Receiver Name     Item Units Freight Payment Type  BillNo    Status  \
# 1  Abdulkadir Ramzan  Package     1     300         PAID  159704  RECEIVED
# 2      Vision Techno      Box     2     600          COD  159703  RECEIVED
# 3      william njoki  Package     1     200          COD       0  RECEIVED
#
# 0  Desc.
# 1  Brown
# 2    NaN
# 3    NaN

# %%
data_dump['Booking DateTime'] = pd.to_datetime(data_dump['Booking DateTime'])

# %%
date_today = pd.Timestamp(date (2022,4,9))
date_yesterday = pd.Timestamp(date(2022,4,8))
print(date_today)
print(date_yesterday)
# Out:
# 2022-04-09 00:00:00
# 2022-04-08 00:00:00

# %%
dispatch_data = data_dump['WB No.'].contains('HO') & data_dump['Booking DateTime']== date_today
dispatch_data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [41], in <cell line: 1>()
# ----> 1 dispatch_data = data_dump['WB No.'].contains('HO') & data_dump['Booking DateTime']== date_today
#       2 dispatch_data
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/generic.py:5583, in NDFrame.__getattr__(self, name)
#    5576 if (
#    5577     name not in self._internal_names_set
#    5578     and name not in self._metadata
#    5579     and name not in self._accessors
#    5580     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5581 ):
#    5582     return self[name]
# -> 5583 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'contains'
